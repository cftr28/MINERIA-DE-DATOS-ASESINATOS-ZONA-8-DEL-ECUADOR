# %%
# !pip install bayesian-optimization
# Out:
# Collecting bayesian-optimization
#   Downloading bayesian_optimization-2.0.0-py3-none-any.whl.metadata (8.9 kB)
# Collecting colorama<0.5.0,>=0.4.6 (from bayesian-optimization)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.10/dist-packages (from bayesian-optimization) (1.26.4)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bayesian-optimization) (1.5.2)
# Requirement already satisfied: scipy<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bayesian-optimization) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.0.0->bayesian-optimization) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.0.0->bayesian-optimization) (3.5.0)
# Downloading bayesian_optimization-2.0.0-py3-none-any.whl (30 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama, bayesian-optimization
# Successfully installed bayesian-optimization-2.0.0 colorama-0.4.6

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.7-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.1.0-py3-none-any.whl (364 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.4/364.4 kB 6.9 MB/s eta 0:00:00
# Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 19.3 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.7-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.9/78.9 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.7 alembic-1.14.0 colorlog-6.9.0 optuna-4.1.0

# %%
import numpy as np #Operaciones matemáticas rápidas sobre matrices
import pandas as pd #biblioteca de análisis y manipulación de datos para Python
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns #permite generar fácilmente gráficos
import statsmodels.api as sm

# Preprocesado y modelado
# ------------------------------------------------------------------------------
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC # Importar el clasificador SVM
from sklearn.tree import export_graphviz
from sklearn.tree import export_text
from sklearn.model_selection import GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
# Out:
# Mounted at /content/drive

# %%
# Especifica la ruta al archivo en Google Drive
file_path = '/content/drive/My Drive/DATASET_BALANCEADO_LIST.csv'
df = pd.read_csv(file_path)
df
# Out:
#        DIA  HORA_INFRACCION  ARMA  EDAD  LUGAR  SEXO  ANTECEDENTES  \
# 0        3                0     1     1      1     1             1
# 1        3                2     2     2      1     1             1
# 2        2                0     2     2      2     1             1
# 3        4                2     1     3      1     1             1
# 4        3                3     1     2      1     1             1
# ...    ...              ...   ...   ...    ...   ...           ...
# 11763    4                2     5     4      2     2             2
# 11764    4                2     5     4      2     2             2
# 11765    4                2     5     4      2     2             2
# 11766    4                2     5     4      2     2             2
# 11767    4                2     5     4      2     2             2
#
#        AREA_DEL_HECHO  DISTRITO  PRESUNTA_MOTIVACION
# 0                   1         2                    1
# 1                   1         1                    2
# 2                   1         1                    2
# 3                   1         3                    1
# 4                   1         1                    2
# ...               ...       ...                  ...
# 11763               2         3                    6
# 11764               2         3                    6
# 11765               2         3                    6
# 11766               2         3                    6
# 11767               2         3                    6
#
# [11768 rows x 10 columns]

# %%
#verifico datos nulos
df.isnull().sum()
# Out:
# DIA                    0
# HORA_INFRACCION        0
# ARMA                   0
# EDAD                   0
# LUGAR                  0
# SEXO                   0
# ANTECEDENTES           0
# AREA_DEL_HECHO         0
# DISTRITO               0
# PRESUNTA_MOTIVACION    0
# dtype: int64

# %%
ds=pd.DataFrame(df)
#Presenta el numero de filas
print("El número de filas(observaciones) es: ",ds.shape[0])

#Presenta el numero de columnas
print("El número de columnas(variables) es: ",len(ds.columns))
# Out:
# El número de filas(observaciones) es:  11768
# El número de columnas(variables) es:  10

# %%
# tipos de la variables
ds.dtypes
# Out:
# DIA                    int64
# HORA_INFRACCION        int64
# ARMA                   int64
# EDAD                   int64
# LUGAR                  int64
# SEXO                   int64
# ANTECEDENTES           int64
# AREA_DEL_HECHO         int64
# DISTRITO               int64
# PRESUNTA_MOTIVACION    int64
# dtype: object

# %%
print(df['PRESUNTA_MOTIVACION'].unique())# datos en texto
# Out:
# [1 2 3 4 5 6]

# %%
print(df['DISTRITO'].unique())# datos en texto
# Out:
# [2 1 3]

# %%
print(df['ANTECEDENTES'].unique())# datos en texto
# Out:
# [1 2]

# %%
print(df['AREA_DEL_HECHO'].unique())# datos en texto
# Out:
# [1 2]

# %%
print(df['LUGAR'].unique())# datos en texto
# Out:
# [1 2]

# %%
print(df['DIA'].unique())# datos en texto
# Out:
# [3 2 4 1]

# %%
print(df['EDAD'].unique())# datos en texto
# Out:
# [1 2 3 4]

# %%
print(df['HORA_INFRACCION'].unique())# datos en texto
# Out:
# [0 2 3 1]

# %%
print(df['ARMA'].unique())# datos en texto
# Out:
# [1 2 3 4 5]

# %%
print(df['SEXO'].unique())# datos en texto
# Out:
# [1 2]

# %%
df.head()
# Out:
#    DIA  HORA_INFRACCION  ARMA  EDAD  LUGAR  SEXO  ANTECEDENTES  \
# 0    3                0     1     1      1     1             1
# 1    3                2     2     2      1     1             1
# 2    2                0     2     2      2     1             1
# 3    4                2     1     3      1     1             1
# 4    3                3     1     2      1     1             1
#
#    AREA_DEL_HECHO  DISTRITO  PRESUNTA_MOTIVACION
# 0               1         2                    1
# 1               1         1                    2
# 2               1         1                    2
# 3               1         3                    1
# 4               1         1                    2

# %%
df.sample(10)
# Out:
#       DIA  HORA_INFRACCION  ARMA  EDAD  LUGAR  SEXO  ANTECEDENTES  \
# 923     2                3     4     2      2     1             2
# 8079    1                0     2     1      2     2             2
# 1668    3                3     1     1      1     1             2
# 5918    1                3     1     2      1     1             1
# 4401    2                1     1     2      2     1             1
# 2067    3                3     1     2      1     1             2
# 4617    2                2     1     2      1     1             1
# 7770    1                0     2     1      1     2             2
# 3140    1                3     1     2      1     1             1
# 6323    3                3     1     2      1     1             1
#
#       AREA_DEL_HECHO  DISTRITO  PRESUNTA_MOTIVACION
# 923                1         2                    2
# 8079               2         1                    3
# 1668               1         1                    2
# 5918               1         2                    2
# 4401               1         1                    2
# 2067               1         1                    2
# 4617               1         2                    2
# 7770               2         1                    1
# 3140               1         2                    2
# 6323               1         1                    2

# %%
#corelacion
corr_df = df.corr(method='pearson')

plt.figure(figsize=(8, 6))
sns.heatmap(corr_df, annot=True)
plt.show()

# %%
X = df.iloc[:, [4,0,1,3,8,7,9,6,2]] # atributos de entrada seran las primeras columnas
Y = df.iloc[:,[5]] # atributos de destino

#presentacion de los atributos de entrada
X.head()
# Out:
#    LUGAR  DIA  HORA_INFRACCION  EDAD  DISTRITO  AREA_DEL_HECHO  \
# 0      1    3                0     1         2               1
# 1      1    3                2     2         1               1
# 2      2    2                0     2         1               1
# 3      1    4                2     3         3               1
# 4      1    3                3     2         1               1
#
#    PRESUNTA_MOTIVACION  ANTECEDENTES  ARMA
# 0                    1             1     1
# 1                    2             1     2
# 2                    2             1     2
# 3                    1             1     1
# 4                    2             1     1

# %%
#presentacion de los atributos de destino
Y.head()
# Out:
#    SEXO
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=7)

print('Son {} datos para entrenamiento y {} datos para prueba'.format(X_train.shape[0], X_test.shape[0]))
# Out:
# Son 9414 datos para entrenamiento y 2354 datos para prueba

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9414 entries, 80 to 9412
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   LUGAR                9414 non-null   int64
#  1   DIA                  9414 non-null   int64
#  2   HORA_INFRACCION      9414 non-null   int64
#  3   EDAD                 9414 non-null   int64
#  4   DISTRITO             9414 non-null   int64
#  5   AREA_DEL_HECHO       9414 non-null   int64
#  6   PRESUNTA_MOTIVACION  9414 non-null   int64
#  7   ANTECEDENTES         9414 non-null   int64
#  8   ARMA                 9414 non-null   int64
# dtypes: int64(9)
# memory usage: 735.5 KB

# %%
import optuna
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score

# Función para evaluar el modelo SVM con diferentes kernels, parámetros C y decision_function_shape
def svm_evaluate(trial):
    # Sugerir un valor para el parámetro C entre 1 y 100
    C = trial.suggest_float('C', 1, 100)

    # Sugerir el tipo de kernel como un valor categórico
    kernel = trial.suggest_categorical('kernel', ['linear', 'poly', 'rbf', 'sigmoid'])

    # Sugerir la estrategia 'ovo' (uno contra uno) o 'ovr' (uno contra todos)
    decision_function_shape = trial.suggest_categorical('decision_function_shape', ['ovo', 'ovr'])

    # Crear el clasificador SVM con los parámetros sugeridos
    svc = SVC(C=C, kernel=kernel, decision_function_shape=decision_function_shape, random_state=7)

    # Ajustar el modelo con los datos de entrenamiento
    svc.fit(X_train, y_train.values.ravel())

    # Realizar predicciones en el conjunto de prueba
    y_pred = svc.predict(X_test)

    # Retornar el precision_score como métrica a optimizar
    return precision_score(y_test, y_pred, average='micro')

# Definir el estudio de Optuna para maximizar la precisión
study = optuna.create_study(direction='maximize')

# Ejecutar la optimización (n_trials = número de intentos)
study.optimize(svm_evaluate, n_trials=25)

# Obtener los mejores parámetros encontrados
best_params = study.best_params
print("Mejores hiperparámetros encontrados:", best_params)

# Obtener la mejor precisión alcanzada
best_precision = study.best_value
print(f"La mejor precisión alcanzada es: {best_precision * 100:.2f}%")
# Out:
# [I 2024-12-04 19:45:00,538] A new study created in memory with name: no-name-e55c051b-85bb-4e4f-b5be-db7950ccc066
# [I 2024-12-04 19:45:01,290] Trial 0 finished with value: 0.9821580288870009 and parameters: {'C': 55.0097122349383, 'kernel': 'linear', 'decision_function_shape': 'ovo'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 19:45:02,409] Trial 1 finished with value: 0.9821580288870009 and parameters: {'C': 98.18175340074652, 'kernel': 'linear', 'decision_function_shape': 'ovo'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 19:45:05,659] Trial 2 finished with value: 0.9813084112149533 and parameters: {'C': 68.01370404679669, 'kernel': 'rbf', 'decision_function_shape': 'ovo'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 19:45:31,331] Trial 3 finished with value: 0.9821580288870009 and parameters: {'C': 41.01395191377187, 'kernel': 'poly', 'decision_function_shape': 'ovr'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 19:45:36,026] Trial 4 finished with value: 0.40951571792693287 and parameters: {'C': 63.83570288510558, 'kernel': 'sigmoid', 'decision_function_shape': 'ovr'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 19:45:41,344] Trial 5 finished with value: 0.40951571792693287 and parameters: {'C': 4.159853744826449, 'kernel': 'sigmoid', 'decision_function_shape': 'ovo'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 19:45:47,036] Trial 6 finished with value: 0.40951571792693287 and parameters: {'C': 38.09151810355322, 'kernel': 'sigmoid', 'decision_function_shape': 'ovo'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 19:46:03,392] Trial 7 finished with value: 0.9821580288870009 and parameters: {'C': 7.924449073903889, 'kernel': 'poly', 'decision_function_shape': 'ovo'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 19:46:08,083] Trial 8 finished with value: 0.40951571792693287 and parameters: {'C': 66.34595822477296, 'kernel': 'sigmoid', 'decision_function_shape': 'ovo'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 19:46:08,528] Trial 9 finished with value: 0.9821580288870009 and parameters: {'C': 26.783493301920622, 'kernel': 'linear', 'decision_function_shape': 'ovr'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 19:46:09,760] Trial 10 finished with value: 0.9821580288870009 and parameters: {'C': 90.81464087885115, 'kernel': 'linear', 'decision_function_shape': 'ovr'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 19:46:11,385] Trial 11 finished with value: 0.9821580288870009 and parameters: {'C': 96.99261219379804, 'kernel': 'linear', 'decision_function_shape': 'ovo'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 19:46:12,972] Trial 12 finished with value: 0.9821580288870009 and parameters: {'C': 82.64520451593955, 'kernel': 'linear', 'decision_function_shape': 'ovo'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 19:46:14,110] Trial 13 finished with value: 0.9821580288870009 and parameters: {'C': 56.95255863631015, 'kernel': 'linear', 'decision_function_shape': 'ovo'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 19:46:16,655] Trial 14 finished with value: 0.9813084112149533 and parameters: {'C': 80.30640009712431, 'kernel': 'rbf', 'decision_function_shape': 'ovo'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 19:46:17,052] Trial 15 finished with value: 0.9821580288870009 and parameters: {'C': 22.26092578942317, 'kernel': 'linear', 'decision_function_shape': 'ovo'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 19:46:17,653] Trial 16 finished with value: 0.9821580288870009 and parameters: {'C': 49.6809273831814, 'kernel': 'linear', 'decision_function_shape': 'ovo'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 19:46:18,423] Trial 17 finished with value: 0.9821580288870009 and parameters: {'C': 77.6786042208493, 'kernel': 'linear', 'decision_function_shape': 'ovo'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 20:08:30,177] Trial 18 finished with value: 0.9821580288870009 and parameters: {'C': 98.35571253318479, 'kernel': 'poly', 'decision_function_shape': 'ovr'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 20:08:32,526] Trial 19 finished with value: 0.9821580288870009 and parameters: {'C': 47.97536218288763, 'kernel': 'rbf', 'decision_function_shape': 'ovo'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 20:08:32,957] Trial 20 finished with value: 0.9821580288870009 and parameters: {'C': 25.619772002184362, 'kernel': 'linear', 'decision_function_shape': 'ovo'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 20:08:53,485] Trial 21 finished with value: 0.9821580288870009 and parameters: {'C': 38.0545618016566, 'kernel': 'poly', 'decision_function_shape': 'ovr'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 20:09:20,722] Trial 22 finished with value: 0.9821580288870009 and parameters: {'C': 42.492151851215375, 'kernel': 'poly', 'decision_function_shape': 'ovr'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 20:20:56,496] Trial 23 finished with value: 0.9821580288870009 and parameters: {'C': 58.81330288527718, 'kernel': 'poly', 'decision_function_shape': 'ovr'}. Best is trial 0 with value: 0.9821580288870009.
# [I 2024-12-04 20:21:12,558] Trial 24 finished with value: 0.9821580288870009 and parameters: {'C': 15.07282599923856, 'kernel': 'poly', 'decision_function_shape': 'ovr'}. Best is trial 0 with value: 0.9821580288870009.
# Mejores hiperparámetros encontrados: {'C': 55.0097122349383, 'kernel': 'linear', 'decision_function_shape': 'ovo'}
# La mejor precisión alcanzada es: 98.22%

# %%
# Cargamos la librería Support Vector Classifier
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report

# Llamamos al constructor de Support Vector Machine
classifier = SVC(kernel='linear', C=55, decision_function_shape='ovo')

# Entrenamos el modelo
svm_modelo = classifier.fit(X_train, y_train)

# Realizamos predicciones en el conjunto de prueba
y_pred = classifier.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Resumen de las predicciones hechas por el clasificador
from sklearn import metrics
reporte = metrics.classification_report(y_test, y_pred,output_dict=True)
pre = pd.DataFrame(reporte).transpose()
print(pre)
pre.to_excel("resumen_precision_sexo.xlsx")
# Out:
#               precision    recall  f1-score      support
# 1              0.968657  1.000000  0.984079  1298.000000
# 2              1.000000  0.960227  0.979710  1056.000000
# accuracy       0.982158  0.982158  0.982158     0.982158
# macro avg      0.984328  0.980114  0.981894  2354.000000
# weighted avg   0.982717  0.982158  0.982119  2354.000000

# %%
from sklearn import metrics
import pandas as pd

reporte = metrics.classification_report(y_test, y_pred, output_dict=True)

# Extraer solo la precisión de cada clase, excluyendo métricas agregadas
precision = {class_name: metrics['precision'] for class_name, metrics in reporte.items() if isinstance(metrics, dict)}

# Convertir a DataFrame
precision_df = pd.DataFrame(list(precision.items()), columns=['Clase', 'Precisión'])

# Imprimir el DataFrame
print(precision_df)
# Out:
#           Clase  Precisión
# 0             1   0.968657
# 1             2   1.000000
# 2     macro avg   0.984328
# 3  weighted avg   0.982717

# %%
y_test.head()
# Out:
#    SEXO
# 0     1
# 1     2
# 2     1
# 3     1
# 4     1

# %%
#Matriz de confusion
matriz=confusion_matrix(y_test, y_pred)
ax= plt.subplot()
sns.heatmap(matriz, annot=True, cmap="Blues",fmt='g');
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix');

# %%
cm = confusion_matrix(y_test, y_pred)

mc= pd.DataFrame(cm)
print(mc)
mc.to_excel("matriz_confusion_sexo.xlsx")
# Out:
#       0     1
# 0  1298     0
# 1    42  1014

# %%
#Para concatenar variables
import pandas as pd

prediccion = pd.DataFrame(y_pred,columns=['sexo_prediccion'])
original = y_test
original.reset_index(drop=True, inplace=True)
df_combined = pd.concat([prediccion,original], axis=1)
df_combined.head(10)
# Out:
#    sexo_prediccion  SEXO
# 0                1     1
# 1                2     2
# 2                1     1
# 3                1     1
# 4                1     1
# 5                2     2
# 6                2     2
# 7                1     1
# 8                2     2
# 9                1     1

# %%
from sklearn import model_selection
from sklearn.metrics import make_scorer, precision_score, accuracy_score, recall_score

def v_cruzada_svm(svm_modelo, X_train, y_train):
    # Convertir y_train a un array unidimensional
    y_train = y_train.values.ravel()

    # Definir los scorers para precisión, accuracy y recall
    precision_scorer = make_scorer(precision_score, average='micro')
    accuracy_scorer = make_scorer(accuracy_score)  # No necesita parámetro average
    recall_scorer = make_scorer(recall_score, average='micro')

    seed = 7
    kfold = model_selection.KFold(n_splits=5, random_state=seed, shuffle=True)  # shuffle para activar el random state

    # Realiza la validación cruzada para precisión
    cv_results_precision = model_selection.cross_val_score(svm_modelo, X_train, y_train, cv=kfold, scoring=precision_scorer)
    print("Iteraciones validación cruzada (Precisión):\n", cv_results_precision)
    msg_precision = "%f (%f)" % (cv_results_precision.mean(), cv_results_precision.std())
    print("Precisión media:\n", msg_precision)

    # Realiza la validación cruzada para accuracy
    cv_results_accuracy = model_selection.cross_val_score(svm_modelo, X_train, y_train, cv=kfold, scoring=accuracy_scorer)
    print("Iteraciones validación cruzada (Accuracy):\n", cv_results_accuracy)
    msg_accuracy = "%f (%f)" % (cv_results_accuracy.mean(), cv_results_accuracy.std())
    print("Accuracy media:\n", msg_accuracy)

    # Realiza la validación cruzada para recall
    cv_results_recall = model_selection.cross_val_score(svm_modelo, X_train, y_train, cv=kfold, scoring=recall_scorer)
    print("Iteraciones validación cruzada (Recall):\n", cv_results_recall)
    msg_recall = "%f (%f)" % (cv_results_recall.mean(), cv_results_recall.std())
    print("Recall media:\n", msg_recall)

# %%
v_cruzada_svm(svm_modelo, X_train, y_train)
# Out:
# Iteraciones validación cruzada (Precisión):
#  [0.9803505  0.97610196 0.98353691 0.97610196 0.98140276]
# Precisión media:
#  0.979499 (0.002957)
# Iteraciones validación cruzada (Accuracy):
#  [0.9803505  0.97610196 0.98353691 0.97610196 0.98140276]
# Accuracy media:
#  0.979499 (0.002957)
# Iteraciones validación cruzada (Recall):
#  [0.9803505  0.97610196 0.98353691 0.97610196 0.98140276]
# Recall media:
#  0.979499 (0.002957)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score

# Assuming y_pred and y_test are defined
print('Precision: ', precision_score(y_test, y_pred, average='micro') * 100)
print('Accuracy: ', accuracy_score(y_test, y_pred) * 100)
print('Recall: ', recall_score(y_test, y_pred, average='micro') * 100)
# Out:
# Precision:  98.21580288870008
# Accuracy:  98.21580288870008
# Recall:  98.21580288870008

# %%
df_combined['SEXO'] = df_combined['SEXO'].apply(lambda x:
                                                'Masculino' if x == 1 else
                                                'Femenino')

# %%
df_combined['sexo_prediccion'] = df_combined['sexo_prediccion'].apply(lambda x:
                                                                       'Masculino' if x == 1 else
                                                                       'Femenino')

# %%
import seaborn as sns #permite generar fácilmente elegantes gráficos, proporciona una interfaz de alto nivel que es realmente sencilla de aprender.
ax = plt.subplots(figsize = (45,10))
ncount=len(df_combined)
sns.countplot(x='SEXO',hue = 'SEXO', data = df_combined, ax = ax[1]) #Muestre el conteo de observaciones en cada contenedor categórico usando barras.
ax[1].set_title('SEXO')

for p in ax[1].patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax[1].annotate('{:.1f}%'.format(100.*y/ncount), (x.mean(), y),
            ha='center', va='bottom') # set the alignment of the text

#Guardamos la figura de barras original
ax[0].savefig("barras_original_SEXO.png")

# %%
ax = plt.subplots(figsize = (45,10))
ncount=len(df_combined)
sns.countplot(x='sexo_prediccion',hue = 'sexo_prediccion', data = df_combined, ax = ax[1]) #Muestre el conteo de observaciones en cada contenedor categórico usando barras.
ax[1].set_title('sexo_prediccion')


for p in ax[1].patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax[1].annotate('{:.1f}%'.format(100.*y/ncount), (x.mean(), y),
            ha='center', va='bottom') # set the alignment of the text

#Guardamos la figura de barras de predicción
ax[0].savefig("barras_prediccion_sexo.png")

# %%
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt
pca = PCA(n_components=2)
X_train_2D = pca.fit_transform(X_train)
# Entrenar el modelo con los datos reducidos por PCA

classifier_pca = SVC(kernel='linear', C=55, decision_function_shape='ovo')
classifier_pca.fit(X_train_2D, y_train.values.ravel())  # Entrenar el modelo con las 2 dimensiones

# Crear la malla de puntos para graficar
x_min, x_max = X_train_2D[:, 0].min() - 1, X_train_2D[:, 0].max() + 1
y_min, y_max = X_train_2D[:, 1].min() - 1, X_train_2D[:, 1].max() + 1
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 300),
                     np.linspace(y_min, y_max, 300))

# Obtener el puntaje de decisión sobre la malla
Z = classifier_pca.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Graficar el área de decisión y el hiperplano
plt.contourf(xx, yy, Z > 0, alpha=0.5, cmap=plt.cm.Paired)  # Regiones de decisión
plt.contour(xx, yy, Z, levels=[0], linewidths=2, colors='red', linestyles='--')  # Hiperplano

# Graficar los puntos de las clases
plt.scatter(X_train_2D[y_train.values.ravel() == 1, 0], X_train_2D[y_train.values.ravel() == 1, 1], color='blue', label='Clase Masculino (1)')
plt.scatter(X_train_2D[y_train.values.ravel() == 2, 0], X_train_2D[y_train.values.ravel() == 2, 1], color='green', label='Clase Femenino (2)')

# Etiquetas y título
plt.title('Hiperplano de Separación:Lugar Clasificación Masculino vs Femenino', fontsize=14)
plt.xlabel('Componente Principal 1', fontsize=12)
plt.ylabel('Componente Principal 2', fontsize=12)
plt.legend(loc='best')
plt.tight_layout()

# Mostrar la gráfica
plt.show()
