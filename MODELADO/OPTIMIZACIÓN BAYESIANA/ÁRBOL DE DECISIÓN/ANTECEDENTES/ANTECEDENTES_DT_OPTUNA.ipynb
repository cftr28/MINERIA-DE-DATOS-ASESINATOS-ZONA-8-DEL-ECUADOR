# %%
# !pip install bayesian-optimization
# Out:
# Requirement already satisfied: bayesian-optimization in /usr/local/lib/python3.10/dist-packages (2.0.1)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from bayesian-optimization) (0.4.6)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.10/dist-packages (from bayesian-optimization) (1.26.4)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bayesian-optimization) (1.5.2)
# Requirement already satisfied: scipy<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bayesian-optimization) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.0.0->bayesian-optimization) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.0.0->bayesian-optimization) (3.5.0)

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (4.1.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.14.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.8)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)

# %%
import numpy as np #Operaciones matemáticas rápidas sobre matrices
import pandas as pd #biblioteca de análisis y manipulación de datos para Python
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns #permite generar fácilmente gráficos
import statsmodels.api as sm

# Preprocesado y modelado
# ------------------------------------------------------------------------------
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz
from sklearn.tree import export_text
from sklearn.model_selection import GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
# Out:
# Mounted at /content/drive

# %%
# Especifica la ruta al archivo en Google Drive
file_path = '/content/drive/My Drive/DATASET_BALANCEADO_LIST.csv'
df = pd.read_csv(file_path)
df
# Out:
#        DIA  HORA_INFRACCION  ARMA  EDAD  LUGAR  SEXO  ANTECEDENTES  \
# 0        3                0     1     1      1     1             1
# 1        3                2     2     2      1     1             1
# 2        2                0     2     2      2     1             1
# 3        4                2     1     3      1     1             1
# 4        3                3     1     2      1     1             1
# ...    ...              ...   ...   ...    ...   ...           ...
# 11763    4                2     5     4      2     2             2
# 11764    4                2     5     4      2     2             2
# 11765    4                2     5     4      2     2             2
# 11766    4                2     5     4      2     2             2
# 11767    4                2     5     4      2     2             2
#
#        AREA_DEL_HECHO  DISTRITO  PRESUNTA_MOTIVACION
# 0                   1         2                    1
# 1                   1         1                    2
# 2                   1         1                    2
# 3                   1         3                    1
# 4                   1         1                    2
# ...               ...       ...                  ...
# 11763               2         3                    6
# 11764               2         3                    6
# 11765               2         3                    6
# 11766               2         3                    6
# 11767               2         3                    6
#
# [11768 rows x 10 columns]

# %%
#verifico datos nulos
df.isnull().sum()
# Out:
# DIA                    0
# HORA_INFRACCION        0
# ARMA                   0
# EDAD                   0
# LUGAR                  0
# SEXO                   0
# ANTECEDENTES           0
# AREA_DEL_HECHO         0
# DISTRITO               0
# PRESUNTA_MOTIVACION    0
# dtype: int64

# %%
ds=pd.DataFrame(df)
#Presenta el numero de filas
print("El número de filas(observaciones) es: ",ds.shape[0])

#Presenta el numero de columnas
print("El número de columnas(variables) es: ",len(ds.columns))
# Out:
# El número de filas(observaciones) es:  11768
# El número de columnas(variables) es:  10

# %%
# tipos de la variables
ds.dtypes
# Out:
# DIA                    int64
# HORA_INFRACCION        int64
# ARMA                   int64
# EDAD                   int64
# LUGAR                  int64
# SEXO                   int64
# ANTECEDENTES           int64
# AREA_DEL_HECHO         int64
# DISTRITO               int64
# PRESUNTA_MOTIVACION    int64
# dtype: object

# %%
print(df['PRESUNTA_MOTIVACION'].unique())# datos en texto
# Out:
# [1 2 3 4 5 6]

# %%
print(df['DISTRITO'].unique())# datos en texto
# Out:
# [2 1 3]

# %%
print(df['ANTECEDENTES'].unique())# datos en texto
# Out:
# [1 2]

# %%
print(df['AREA_DEL_HECHO'].unique())# datos en texto
# Out:
# [1 2]

# %%
print(df['LUGAR'].unique())# datos en texto
# Out:
# [1 2]

# %%
print(df['DIA'].unique())# datos en texto
# Out:
# [3 2 4 1]

# %%
print(df['EDAD'].unique())# datos en texto
# Out:
# [1 2 3 4]

# %%
print(df['HORA_INFRACCION'].unique())# datos en texto
# Out:
# [0 2 3 1]

# %%
print(df['ARMA'].unique())# datos en texto
# Out:
# [1 2 3 4 5]

# %%
print(df['SEXO'].unique())# datos en texto
# Out:
# [1 2]

# %%
df.head()
# Out:
#    DIA  HORA_INFRACCION  ARMA  EDAD  LUGAR  SEXO  ANTECEDENTES  \
# 0    3                0     1     1      1     1             1
# 1    3                2     2     2      1     1             1
# 2    2                0     2     2      2     1             1
# 3    4                2     1     3      1     1             1
# 4    3                3     1     2      1     1             1
#
#    AREA_DEL_HECHO  DISTRITO  PRESUNTA_MOTIVACION
# 0               1         2                    1
# 1               1         1                    2
# 2               1         1                    2
# 3               1         3                    1
# 4               1         1                    2

# %%
df.sample(10)
# Out:
#       DIA  HORA_INFRACCION  ARMA  EDAD  LUGAR  SEXO  ANTECEDENTES  \
# 4995    1                3     1     1      1     1             1
# 2700    2                3     1     3      1     1             1
# 6108    1                2     1     2      1     1             1
# 2482    1                2     1     2      1     1             2
# 3777    1                2     1     2      1     1             1
# 6601    1                2     1     2      1     2             1
# 8503    1                0     3     1      2     2             2
# 8549    2                0     3     1      2     2             2
# 8881    2                1     3     1      2     2             2
# 1841    3                3     1     2      1     1             1
#
#       AREA_DEL_HECHO  DISTRITO  PRESUNTA_MOTIVACION
# 4995               1         1                    2
# 2700               1         2                    2
# 6108               1         2                    2
# 2482               1         2                    2
# 3777               1         2                    2
# 6601               1         2                    2
# 8503               2         1                    3
# 8549               2         1                    3
# 8881               2         1                    4
# 1841               1         1                    2

# %%
#corelacion
corr_df = df.corr(method='pearson')

plt.figure(figsize=(8, 6))
sns.heatmap(corr_df, annot=True)
plt.show()

# %%
X = df.iloc[:, [5,0,1,3,4,8,9,7,2]] # atributos de entrada seran las primeras columnas
Y = df.iloc[:,[6]] # atributos de destino

#presentacion de los atributos de entrada
X.head()
# Out:
#    SEXO  DIA  HORA_INFRACCION  EDAD  LUGAR  DISTRITO  PRESUNTA_MOTIVACION  \
# 0     1    3                0     1      1         2                    1
# 1     1    3                2     2      1         1                    2
# 2     1    2                0     2      2         1                    2
# 3     1    4                2     3      1         3                    1
# 4     1    3                3     2      1         1                    2
#
#    AREA_DEL_HECHO  ARMA
# 0               1     1
# 1               1     2
# 2               1     2
# 3               1     1
# 4               1     1

# %%
#presentacion de los atributos de destino
Y.head()
# Out:
#    ANTECEDENTES
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=7)

print('Son {} datos para entrenamiento y {} datos para prueba'.format(X_train.shape[0], X_test.shape[0]))
# Out:
# Son 9414 datos para entrenamiento y 2354 datos para prueba

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9414 entries, 80 to 9412
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SEXO                 9414 non-null   int64
#  1   DIA                  9414 non-null   int64
#  2   HORA_INFRACCION      9414 non-null   int64
#  3   EDAD                 9414 non-null   int64
#  4   LUGAR                9414 non-null   int64
#  5   DISTRITO             9414 non-null   int64
#  6   PRESUNTA_MOTIVACION  9414 non-null   int64
#  7   AREA_DEL_HECHO       9414 non-null   int64
#  8   ARMA                 9414 non-null   int64
# dtypes: int64(9)
# memory usage: 735.5 KB

# %%
import optuna
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score

# Función de objetivo para la optimización de hiperparámetros
def objective(trial):
    # Definición de los hiperparámetros
    criterion = trial.suggest_categorical('criterion', ['gini', 'entropy'])
    max_depth = trial.suggest_int('max_depth', 3, 10)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 25)

    # Crear y entrenar el modelo
    model = DecisionTreeClassifier(
        criterion=criterion,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf
    )

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    # Devuelve la métrica de precisión
    return precision_score(y_test, y_pred, average='micro')

# Crear un estudio
study = optuna.create_study(direction='maximize')  # Maximizar la precisión
study.optimize(objective, n_trials=100)  # Ejecutar la optimización

# Mostrar los mejores parámetros encontrados
print("Mejores hiperparámetros encontrados:")
print(study.best_params)
print("Mejor precisión:", study.best_value)
# Out:
# [I 2024-12-11 13:54:20,239] A new study created in memory with name: no-name-684f3c1c-3602-4b2d-ae82-a1c6a32a3b91
# [I 2024-12-11 13:54:20,278] Trial 0 finished with value: 0.9039932030586236 and parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 6}. Best is trial 0 with value: 0.9039932030586236.
# [I 2024-12-11 13:54:20,315] Trial 1 finished with value: 0.9039932030586236 and parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 19}. Best is trial 0 with value: 0.9039932030586236.
# [I 2024-12-11 13:54:20,340] Trial 2 finished with value: 0.9065420560747663 and parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 6}. Best is trial 2 with value: 0.9065420560747663.
# [I 2024-12-11 13:54:20,376] Trial 3 finished with value: 0.905267629566695 and parameters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 10}. Best is trial 2 with value: 0.9065420560747663.
# [I 2024-12-11 13:54:20,394] Trial 4 finished with value: 0.9039932030586236 and parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 2 with value: 0.9065420560747663.
# [I 2024-12-11 13:54:20,419] Trial 5 finished with value: 0.905267629566695 and parameters: {'criterion': 'gini', 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 23}. Best is trial 2 with value: 0.9065420560747663.
# [I 2024-12-11 13:54:20,446] Trial 6 finished with value: 0.9061172472387425 and parameters: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 2 with value: 0.9065420560747663.
# [I 2024-12-11 13:54:20,480] Trial 7 finished with value: 0.9048428207306712 and parameters: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 6}. Best is trial 2 with value: 0.9065420560747663.
# [I 2024-12-11 13:54:20,544] Trial 8 finished with value: 0.9061172472387425 and parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 22}. Best is trial 2 with value: 0.9065420560747663.
# [I 2024-12-11 13:54:20,616] Trial 9 finished with value: 0.9078164825828378 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 9 with value: 0.9078164825828378.
# [I 2024-12-11 13:54:20,671] Trial 10 finished with value: 0.9056924384027187 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 15}. Best is trial 9 with value: 0.9078164825828378.
# [I 2024-12-11 13:54:20,722] Trial 11 finished with value: 0.9065420560747663 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 10}. Best is trial 9 with value: 0.9078164825828378.
# [I 2024-12-11 13:54:20,776] Trial 12 finished with value: 0.9061172472387425 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 9 with value: 0.9078164825828378.
# [I 2024-12-11 13:54:20,858] Trial 13 finished with value: 0.9065420560747663 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 8}. Best is trial 9 with value: 0.9078164825828378.
# [I 2024-12-11 13:54:20,905] Trial 14 finished with value: 0.9061172472387425 and parameters: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 14}. Best is trial 9 with value: 0.9078164825828378.
# [I 2024-12-11 13:54:20,951] Trial 15 finished with value: 0.905267629566695 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 5}. Best is trial 9 with value: 0.9078164825828378.
# [I 2024-12-11 13:54:21,034] Trial 16 finished with value: 0.9056924384027187 and parameters: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 11}. Best is trial 9 with value: 0.9078164825828378.
# [I 2024-12-11 13:54:21,145] Trial 17 finished with value: 0.907391673746814 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 4}. Best is trial 9 with value: 0.9078164825828378.
# [I 2024-12-11 13:54:21,222] Trial 18 finished with value: 0.9065420560747663 and parameters: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 9 with value: 0.9078164825828378.
# [I 2024-12-11 13:54:21,276] Trial 19 finished with value: 0.9056924384027187 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 17}. Best is trial 9 with value: 0.9078164825828378.
# [I 2024-12-11 13:54:21,319] Trial 20 finished with value: 0.9048428207306712 and parameters: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 8}. Best is trial 9 with value: 0.9078164825828378.
# [I 2024-12-11 13:54:21,367] Trial 21 finished with value: 0.9082412914188616 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:21,431] Trial 22 finished with value: 0.9082412914188616 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:21,497] Trial 23 finished with value: 0.9065420560747663 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 8}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:21,577] Trial 24 finished with value: 0.9061172472387425 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:21,636] Trial 25 finished with value: 0.9082412914188616 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:21,686] Trial 26 finished with value: 0.9048428207306712 and parameters: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 12}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:21,753] Trial 27 finished with value: 0.9061172472387425 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 8}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:21,849] Trial 28 finished with value: 0.907391673746814 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 5}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:21,999] Trial 29 finished with value: 0.905267629566695 and parameters: {'criterion': 'gini', 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 25}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:22,076] Trial 30 finished with value: 0.905267629566695 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 6}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:22,148] Trial 31 finished with value: 0.9078164825828378 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:22,226] Trial 32 finished with value: 0.9069668649107901 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:22,331] Trial 33 finished with value: 0.907391673746814 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:22,591] Trial 34 finished with value: 0.9065420560747663 and parameters: {'criterion': 'gini', 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 7}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:22,732] Trial 35 finished with value: 0.9056924384027187 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:22,808] Trial 36 finished with value: 0.9061172472387425 and parameters: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 2}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:22,874] Trial 37 finished with value: 0.9069668649107901 and parameters: {'criterion': 'gini', 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 6}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:22,934] Trial 38 finished with value: 0.905267629566695 and parameters: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 10}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:22,990] Trial 39 finished with value: 0.9069668649107901 and parameters: {'criterion': 'gini', 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:23,049] Trial 40 finished with value: 0.9065420560747663 and parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 5}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:23,117] Trial 41 finished with value: 0.9078164825828378 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:23,171] Trial 42 finished with value: 0.9078164825828378 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:23,231] Trial 43 finished with value: 0.9061172472387425 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 7}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:23,302] Trial 44 finished with value: 0.9056924384027187 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 20}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:23,359] Trial 45 finished with value: 0.907391673746814 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:23,405] Trial 46 finished with value: 0.9069668649107901 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 2}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:23,459] Trial 47 finished with value: 0.9061172472387425 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 7}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:23,512] Trial 48 finished with value: 0.9048428207306712 and parameters: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 5}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:23,566] Trial 49 finished with value: 0.9039932030586236 and parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 9}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:23,624] Trial 50 finished with value: 0.9069668649107901 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:23,729] Trial 51 finished with value: 0.9078164825828378 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:23,839] Trial 52 finished with value: 0.9061172472387425 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:23,891] Trial 53 finished with value: 0.9078164825828378 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:23,970] Trial 54 finished with value: 0.9056924384027187 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:24,122] Trial 55 finished with value: 0.9065420560747663 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 6}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:24,187] Trial 56 finished with value: 0.907391673746814 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:24,533] Trial 57 finished with value: 0.9061172472387425 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:24,625] Trial 58 finished with value: 0.9056924384027187 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 15}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:24,755] Trial 59 finished with value: 0.907391673746814 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:24,824] Trial 60 finished with value: 0.9061172472387425 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:24,981] Trial 61 finished with value: 0.9078164825828378 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:25,059] Trial 62 finished with value: 0.9082412914188616 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:25,136] Trial 63 finished with value: 0.907391673746814 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:25,270] Trial 64 finished with value: 0.907391673746814 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 5}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:25,361] Trial 65 finished with value: 0.9065420560747663 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 7}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:25,539] Trial 66 finished with value: 0.905267629566695 and parameters: {'criterion': 'gini', 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 6}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:25,620] Trial 67 finished with value: 0.9061172472387425 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:25,726] Trial 68 finished with value: 0.9061172472387425 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 9}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:25,843] Trial 69 finished with value: 0.9056924384027187 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 17}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:25,948] Trial 70 finished with value: 0.9048428207306712 and parameters: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 12}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:26,033] Trial 71 finished with value: 0.9082412914188616 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:26,146] Trial 72 finished with value: 0.9082412914188616 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:26,223] Trial 73 finished with value: 0.907391673746814 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:26,281] Trial 74 finished with value: 0.907391673746814 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 5}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:26,364] Trial 75 finished with value: 0.9056924384027187 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:26,430] Trial 76 finished with value: 0.9069668649107901 and parameters: {'criterion': 'gini', 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 6}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:26,550] Trial 77 finished with value: 0.9061172472387425 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:26,630] Trial 78 finished with value: 0.907391673746814 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 5}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:26,756] Trial 79 finished with value: 0.9061172472387425 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:26,805] Trial 80 finished with value: 0.9082412914188616 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:26,931] Trial 81 finished with value: 0.9065420560747663 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:27,067] Trial 82 finished with value: 0.9082412914188616 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:27,157] Trial 83 finished with value: 0.9082412914188616 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:27,218] Trial 84 finished with value: 0.9065420560747663 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 7}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:27,302] Trial 85 finished with value: 0.9082412914188616 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:27,467] Trial 86 finished with value: 0.9061172472387425 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 5}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:27,625] Trial 87 finished with value: 0.9056924384027187 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:27,771] Trial 88 finished with value: 0.9069668649107901 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 6}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:27,918] Trial 89 finished with value: 0.9069668649107901 and parameters: {'criterion': 'gini', 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 6}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:28,017] Trial 90 finished with value: 0.907391673746814 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:28,164] Trial 91 finished with value: 0.9065420560747663 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:28,318] Trial 92 finished with value: 0.9082412914188616 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:28,494] Trial 93 finished with value: 0.907391673746814 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 5}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:28,626] Trial 94 finished with value: 0.9061172472387425 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:28,744] Trial 95 finished with value: 0.9056924384027187 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:28,912] Trial 96 finished with value: 0.9078164825828378 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:29,040] Trial 97 finished with value: 0.907391673746814 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:29,164] Trial 98 finished with value: 0.9065420560747663 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 7}. Best is trial 21 with value: 0.9082412914188616.
# [I 2024-12-11 13:54:29,226] Trial 99 finished with value: 0.9078164825828378 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.9082412914188616.
# Mejores hiperparámetros encontrados:
# {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 4}
# Mejor precisión: 0.9082412914188616

# %%
#Cargamos la libreria DecisionTreeClasifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, classification_report


#Llamamos al constructor del arbol de decision
classifier = DecisionTreeClassifier(max_depth=7, min_samples_split=7,min_samples_leaf=4, criterion='entropy')

#Entrenamos el modelo
arbol_modelo = classifier.fit(X_train,y_train)

y_pred = classifier.predict(X_test)

# %%
figura_arbol = plt.figure(figsize=(180,20)) # Le indicamos las dimensiones que queremos que tenga
plot_tree(arbol_modelo,feature_names=X.columns,filled=True, fontsize=15)
plt.show()

# %%
figura_arbol.savefig("ANTECEDENTES_asesinatos.png")

# %%
# Resumen de las predicciones hechas por el clasificador
from sklearn import metrics
reporte = metrics.classification_report(y_test, y_pred,output_dict=True)
pre = pd.DataFrame(reporte).transpose()
print(pre)
pre.to_excel("resumen_precision_ANTECEDENTES.xlsx")
# Out:
#               precision    recall  f1-score      support
# 1              0.859124  0.980833  0.915953  1200.000000
# 2              0.976626  0.832756  0.898971  1154.000000
# accuracy       0.908241  0.908241  0.908241     0.908241
# macro avg      0.917875  0.906794  0.907462  2354.000000
# weighted avg   0.916727  0.908241  0.907628  2354.000000

# %%
from sklearn import metrics
import pandas as pd

reporte = metrics.classification_report(y_test, y_pred, output_dict=True)

# Extraer solo la precisión de cada clase, excluyendo métricas agregadas
precision = {class_name: metrics['precision'] for class_name, metrics in reporte.items() if isinstance(metrics, dict)}

# Convertir a DataFrame
precision_df = pd.DataFrame(list(precision.items()), columns=['Clase', 'Precisión'])

# Imprimir el DataFrame
print(precision_df)
# Out:
#           Clase  Precisión
# 0             1   0.859124
# 1             2   0.976626
# 2     macro avg   0.917875
# 3  weighted avg   0.916727

# %%
y_test.head()
# Out:
#    ANTECEDENTES
# 0             1
# 1             2
# 2             1
# 3             1
# 4             1

# %%
#Matriz de confusion
matriz=confusion_matrix(y_test, y_pred)
ax= plt.subplot()
sns.heatmap(matriz, annot=True, cmap="Blues",fmt='g');
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix');

# %%
cm = confusion_matrix(y_test, y_pred)

mc= pd.DataFrame(cm)
print(mc)
mc.to_excel("matriz_confusion_ANTECEDENTES.xlsx")
# Out:
#       0    1
# 0  1177   23
# 1   193  961

# %%
#Para concatenar variables
import pandas as pd

prediccion = pd.DataFrame(y_pred,columns=['antecedentes_prediccion'])
original = y_test
original.reset_index(drop=True, inplace=True)
df_combined = pd.concat([prediccion,original], axis=1)
df_combined.head(10)
# Out:
#    antecedentes_prediccion  ANTECEDENTES
# 0                        1             1
# 1                        2             2
# 2                        1             1
# 3                        1             1
# 4                        2             1
# 5                        2             2
# 6                        2             2
# 7                        1             1
# 8                        2             2
# 9                        1             1

# %%
from sklearn import model_selection
from sklearn.metrics import make_scorer, precision_score, accuracy_score, recall_score

def v_cruzada(arbol_modelo, X_train, y_train):
    # Convertir y_train a un array unidimensional
    y_train = y_train.values.ravel()

    # Definir los scorers para precisión, accuracy y recall
    precision_scorer = make_scorer(precision_score, average='micro')
    accuracy_scorer = make_scorer(accuracy_score)  # No necesita parámetro average
    recall_scorer = make_scorer(recall_score, average='micro')

    seed = 7
    kfold = model_selection.KFold(n_splits=5, random_state=seed, shuffle=True)  # shuffle para activar el random state

    # Realiza la validación cruzada para precisión
    cv_results_precision = model_selection.cross_val_score(arbol_modelo, X_train, y_train, cv=kfold, scoring=precision_scorer)
    print("Iteraciones validación cruzada (Precisión):\n", cv_results_precision)
    msg_precision = "%f (%f)" % (cv_results_precision.mean(), cv_results_precision.std())
    print("Precisión media:\n", msg_precision)

    # Realiza la validación cruzada para accuracy
    cv_results_accuracy = model_selection.cross_val_score(arbol_modelo, X_train, y_train, cv=kfold, scoring=accuracy_scorer)
    print("Iteraciones validación cruzada (Accuracy):\n", cv_results_accuracy)
    msg_accuracy = "%f (%f)" % (cv_results_accuracy.mean(), cv_results_accuracy.std())
    print("Accuracy media:\n", msg_accuracy)

    # Realiza la validación cruzada para recall
    cv_results_recall = model_selection.cross_val_score(arbol_modelo, X_train, y_train, cv=kfold, scoring=recall_scorer)
    print("Iteraciones validación cruzada (Recall):\n", cv_results_recall)
    msg_recall = "%f (%f)" % (cv_results_recall.mean(), cv_results_recall.std())
    print("Recall media:\n", msg_recall)

# %%
#Validación cruzada
v_cruzada(arbol_modelo, X_train,y_train)
# Out:
# Iteraciones validación cruzada (Precisión):
#  [0.89484865 0.90918747 0.90175252 0.89909719 0.89851222]
# Precisión media:
#  0.900680 (0.004790)
# Iteraciones validación cruzada (Accuracy):
#  [0.89484865 0.90971853 0.90281466 0.89856612 0.89851222]
# Accuracy media:
#  0.900892 (0.005083)
# Iteraciones validación cruzada (Recall):
#  [0.89484865 0.90918747 0.90175252 0.89909719 0.89851222]
# Recall media:
#  0.900680 (0.004790)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score

# Assuming y_pred and y_test are defined
print('Precision: ', precision_score(y_test, y_pred, average='micro') * 100)
print('Accuracy: ', accuracy_score(y_test, y_pred) * 100)
print('Recall: ', recall_score(y_test, y_pred, average='micro') * 100)
# Out:
# Precision:  90.82412914188616
# Accuracy:  90.82412914188616
# Recall:  90.82412914188616

# %%
df_combined['ANTECEDENTES'] = df_combined['ANTECEDENTES'].apply(lambda x:
                                                                                                    'Si' if x == 1 else
                                                                                                    'No')

# %%
df_combined['antecedentes_prediccion'] = df_combined['antecedentes_prediccion'].apply(lambda x:
                                                                                                     'Si' if x == 1 else
                                                                                                    'No')

# %%
import seaborn as sns #permite generar fácilmente elegantes gráficos, proporciona una interfaz de alto nivel que es realmente sencilla de aprender.
ax = plt.subplots(figsize = (45,10))
ncount=len(df_combined)
sns.countplot(x='ANTECEDENTES',hue = 'ANTECEDENTES', data = df_combined, ax = ax[1]) #Muestre el conteo de observaciones en cada contenedor categórico usando barras.
ax[1].set_title('ANTECEDENTES')

for p in ax[1].patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax[1].annotate('{:.1f}%'.format(100.*y/ncount), (x.mean(), y),
            ha='center', va='bottom') # set the alignment of the text

#Guardamos la figura de barras original
ax[0].savefig("barras_original_ANTECEDENTES.png")

# %%
ax = plt.subplots(figsize = (45,10))
ncount=len(df_combined)
sns.countplot(x='antecedentes_prediccion',hue = 'antecedentes_prediccion', data = df_combined, ax = ax[1]) #Muestre el conteo de observaciones en cada contenedor categórico usando barras.
ax[1].set_title('antecedentes_prediccion')


for p in ax[1].patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax[1].annotate('{:.1f}%'.format(100.*y/ncount), (x.mean(), y),
            ha='center', va='bottom') # set the alignment of the text

#Guardamos la figura de barras de predicción
ax[0].savefig("barras_antecedentes_prediccion.png")
